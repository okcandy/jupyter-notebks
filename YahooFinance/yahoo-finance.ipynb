# %%
import datetime
from datetime import date
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
# %matplotlib inline

# %%
import yfinance as yf
yf.pdr_override()

# %%
#Tickers
tickers = ['AAPL', 'AMZN', 'MSFT', 'META']

#Dates
start_date = '2019-1-1'
today = date.today()

# %%
stock_data = data.DataReader(tickers, start_date, today)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1151 entries, 2019-01-02 to 2023-07-28
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  1151 non-null   float64
#  1   (Adj Close, AMZN)  1151 non-null   float64
#  2   (Adj Close, META)  1151 non-null   float64
#  3   (Adj Close, MSFT)  1151 non-null   float64
#  4   (Close, AAPL)      1151 non-null   float64
#  5   (Close, AMZN)      1151 non-null   float64
#  6   (Close, META)      1151 non-null   float64
#  7   (Close, MSFT)      1151 non-null   float64
#  8   (High, AAPL)       1151 non-null   float64
#  9   (High, AMZN)       1151 non-null   float64
#  10  (High, META)       1151 non-null   float64
#  11  (High, MSFT)       1151 non-null   float64
#  12  (Low, AAPL)        1151 non-null   float64
#  13  (Low, AMZN)        1151 non-null   float64
#  14  (Low, META)        1151 non-null   float64
# ...

# %%
stock_data.head()
# Out:
#             Adj Close                                        Close             \
#                  AAPL       AMZN        META       MSFT       AAPL       AMZN
# Date
# 2019-01-02  37.994488  76.956497  135.679993  96.421867  39.480000  76.956497
# 2019-01-03  34.209965  75.014000  131.740005  92.874725  35.547501  75.014000
# 2019-01-04  35.670357  78.769501  137.949997  97.194237  37.064999  78.769501
# 2019-01-07  35.590969  81.475502  138.050003  97.318199  36.982498  81.475502
# 2019-01-08  36.269436  82.829002  142.529999  98.023819  37.687500  82.829002
#
#                                          High             ...         Low  \
#                   META        MSFT       AAPL       AMZN  ...        META
# Date                                                      ...
# 2019-01-02  135.679993  101.120003  39.712502  77.667999  ...  128.559998
# 2019-01-03  131.740005   97.400002  36.430000  76.900002  ...  131.119995
# ...
